# %% [markdown]
# # Web scraping - Pegando dados etfs do mundo inteiro

# %% [markdown]
# ## Importando bibliotecas

# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: selenium in c:\users\leonortega\anaconda3\lib\site-packages (4.8.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\leonortega\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio~=0.17 in c:\users\leonortega\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\leonortega\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\leonortega\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: async-generator>=1.9 in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: idna in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\leonortega\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\leonortega\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\leonortega\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\leonortega\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\leonortega\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: webdriver-manager in c:\users\leonortega\anaconda3\lib\site-packages (3.8.5)
# Requirement already satisfied: packaging in c:\users\leonortega\anaconda3\lib\site-packages (from webdriver-manager) (22.0)
# Requirement already satisfied: tqdm in c:\users\leonortega\anaconda3\lib\site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: requests in c:\users\leonortega\anaconda3\lib\site-packages (from webdriver-manager) (2.28.1)
# Requirement already satisfied: python-dotenv in c:\users\leonortega\anaconda3\lib\site-packages (from webdriver-manager) (1.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leonortega\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\leonortega\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leonortega\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\leonortega\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.14)
# Requirement already satisfied: colorama in c:\users\leonortega\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.6)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %% [markdown]
# # Como funciona as requisições na internet
# ##### Ao acessar a globo.com por exemplo estamos eviando uma requisição chamada get que vai até o servidor da globo com as matérias armazenadas em algum banco de dados, pra pegar esses dados quando entro no site estou fazendo uma requisição chamada get que é um protocolo http, com a minha internet estou mandando pro servidor da globo me envia ai as últimas noticias do seu banco de dados. E é com esse método get que vamos usar para acessar qualquer site da internet

# %%
#driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#Essa linha de código cria uma instância do driver do Google Chrome para ser usado em um script automatizado
#de testes ou scraping (raspagem de dados) em Python.

# %%
#webdriver ma biblioteca do Selenium que permite a automação de ações no navegador, como clicar em botões,
#preencher formulários e extrair informações de páginas

# %%
#Já o ChromeDriver é um executável que permite a comunicação entre o navegador Google Chrome e a 
#biblioteca Selenium.

# %%
#ChromeDriverManager é usada para instalar automaticamente a versão mais recente do ChromeDriver

# %% [markdown]
# ## Hora de começar a comandar o robô

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get('https://www.etf.com/etfanalytics/etf-finder')
driver.maximize_window()
botao_cookies = driver.find_element("xpath",'//*[@id="cookie-bar"]/p/a[2]')
botao_cookies.click()
#driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#driver.get('https://www.etf.com/etfanalytics/etf-finder') #etf.com tem todos os etfs do mundo inteiro, as 20h da uma bugada pq
# é atualização

# %% [markdown]
# # Conhecer e mapear o processo de coleta de dados no site etf.com

# %%
time.sleep(5)
botao_100 = driver.find_element("xpath",
                               '/html/body/div[4]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span')
                               
driver.execute_script("arguments[0].click();", botao_100)
#botao_100.click()
#driver.execute_script("arguments[0].click();", botao_100)

#Geralmente a variavel.click() funciona
#caso não funcione existe essa forma

# %% [markdown]
# # ACHAR O NÚMERO DE PÁGINAS

# %%
num_paginas = driver.find_element("xpath",'//*[@id="totalPages"]')
num_paginas = int(num_paginas.text.replace("of ",""))
num_paginas
# Out:
# 32

# %% [markdown]
# # For loop para ler as paginas

# %%
lista_tabelas = []
elemento_tabela = driver.find_element("xpath",'//*[@id="finderTable"]')

for pagina in range(1, num_paginas + 1):
    html_tabela = elemento_tabela.get_attribute('outerHTML')
    tabela = pd.read_html(str(html_tabela))[0]
    lista_tabelas.append(tabela)
    botao_avancar = driver.find_element("xpath",'//*[@id="nextPage"]')
    botao_avancar.click()
    #time.sleep(2)  # adiciona uma pausa de 2 segundos para aguardar a página carregar completamente
    
tabela_cadastro_etfs = pd.concat(lista_tabelas)

tabela_cadastro_etfs
# Out:
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VOO                               Vanguard S&P 500 ETF
# 3     VTI                    Vanguard Total Stock Market ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 20   CVLC    Calvert US Large-Cap Core Responsible Index ETF
# 21   CVMC      Calvert US Mid-Cap Core Responsible Index ETF
# 22   CVIE        Calvert International Responsible Index ETF
# 23   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
# 24   USCA       Xtrackers MSCI USA Climate Action Equity ETF
#
#                                           Segment  \
# 0                        Equity: U.S. - Large Cap
# 1                        Equity: U.S. - Large Cap
# 2                        Equity: U.S. - Large Cap
# 3                     Equity: U.S. - Total Market
# 4                        Equity: U.S. - Large Cap
# ..                                            ...
# 20                       Equity: U.S. - Large Cap
# 21                         Equity: U.S. - Mid Cap
# 22  Equity: Developed Markets Ex-U.S. - Large Cap
# 23                       Equity: U.S. - Large Cap
# 24                       Equity: U.S. Environment
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $374.42B
# 1                      Blackrock         0.03%  $306.66B
# 2                       Vanguard         0.03%  $287.12B
# 3                       Vanguard         0.03%  $282.79B
# 4                        Invesco         0.20%  $172.68B
# ..                           ...           ...       ...
# 20                Morgan Stanley         0.15%        --
# 21                Morgan Stanley         0.15%        --
# 22                Morgan Stanley         0.18%        --
# 23                Morgan Stanley         0.14%        --
# 24                           DWS         0.07%        --
#
# [3125 rows x 6 columns]

# %% [markdown]
# # Agora preciso pegar os dados de performace das ações, mas preciso voltar da pagina 32 para 1.

# %%
formulario_voltar = driver.find_element("xpath",'//*[@id="goToPage"]')
formulario_voltar.clear()
formulario_voltar.send_keys("1")
formulario_voltar.send_keys(u'\ue007')

# %% [markdown]
# # Agora posso ler a tabela de rentabilidade

# %%
performace = driver.find_element("xpath", '/html/body/div[4]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/ul/li[2]/span')
performace.click()



lista_tabelas = []
elemento_tabela = driver.find_element("xpath",'//*[@id="finderTable"]')

for pagina in range(1, num_paginas + 1):
    html_tabela = elemento_tabela.get_attribute('outerHTML')
    tabela = pd.read_html(str(html_tabela))[0]
    lista_tabelas.append(tabela)
    botao_avancar = driver.find_element("xpath",'//*[@id="nextPage"]')
    botao_avancar.click()
    #time.sleep(2)  # adiciona uma pausa de 2 segundos para aguardar a página carregar completamente
    
tabela_rentabilidade_etfs = pd.concat(lista_tabelas)

tabela_rentabilidade_etfs
# Out:
#    Ticker                                               Name 1 Month 3 Month  \
# 0     SPY                             SPDR S&P 500 ETF Trust   1.50%   6.90%
# 1     IVV                           iShares Core S&P 500 ETF   1.49%   6.91%
# 2     VOO                               Vanguard S&P 500 ETF   1.53%   6.94%
# 3     VTI                    Vanguard Total Stock Market ETF   0.25%   6.24%
# 4     QQQ                                  Invesco QQQ Trust   6.63%  20.25%
# ..    ...                                                ...     ...     ...
# 20   CVLC    Calvert US Large-Cap Core Responsible Index ETF   0.41%      --
# 21   CVMC      Calvert US Mid-Cap Core Responsible Index ETF  -5.55%      --
# 22   CVIE        Calvert International Responsible Index ETF   1.81%      --
# 23   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...   2.18%      --
# 24   USCA       Xtrackers MSCI USA Climate Action Equity ETF      --      --
#
#        YTD   1 Year 3 Years 5 Years 10 Years As Of Date
# 0    7.27%   -9.01%  19.91%  11.05%   12.19%   04/04/23
# 1    7.27%   -9.02%  19.97%  11.06%   12.24%   04/04/23
# 2    7.29%   -9.02%  19.98%  11.07%   12.24%   04/04/23
# 3    6.75%  -10.30%  19.93%  10.25%   11.74%   04/04/23
# 4   20.01%  -12.94%  21.03%  15.65%   17.73%   04/04/23
# ..     ...      ...     ...     ...      ...        ...
# 20      --       --      --      --       --   04/04/23
# 21      --       --      --      --       --   04/04/23
# 22      --       --      --      --       --   04/04/23
# 23      --       --      --      --       --   04/04/23
# 24      --       --      --      --       --   04/04/23
#
# [3125 rows x 10 columns]

# %%
driver.quit()
print(tabela_rentabilidade_etfs.columns)
tabela_cadastro_etfs = tabela_cadastro_etfs.set_index('Ticker')
tabela_rentabilidade_etfs = tabela_rentabilidade_etfs.set_index("Ticker")
tabela_rentabilidade_etfs = tabela_rentabilidade_etfs[['1 Year', '3 Years', '5 Years']]
# Out:
# Index(['Ticker', 'Name', '1 Month', '3 Month', 'YTD', '1 Year', '3 Years',
#        '5 Years', '10 Years', 'As Of Date'],
#       dtype='object')

# %%
tabela_rentabilidade_etfs
# Out:
#          1 Year 3 Years 5 Years
# Ticker
# SPY      -9.01%  19.91%  11.05%
# IVV      -9.02%  19.97%  11.06%
# VOO      -9.02%  19.98%  11.07%
# VTI     -10.30%  19.93%  10.25%
# QQQ     -12.94%  21.03%  15.65%
# ...         ...     ...     ...
# CVLC         --      --      --
# CVMC         --      --      --
# CVIE         --      --      --
# CDEI         --      --      --
# USCA         --      --      --
#
# [3125 rows x 3 columns]

# %%
tabela_cadastro_etfs
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VOO                                  Vanguard S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
# USCA         Xtrackers MSCI USA Climate Action Equity ETF
#
#                                               Segment  \
# Ticker
# SPY                          Equity: U.S. - Large Cap
# IVV                          Equity: U.S. - Large Cap
# VOO                          Equity: U.S. - Large Cap
# VTI                       Equity: U.S. - Total Market
# QQQ                          Equity: U.S. - Large Cap
# ...                                               ...
# CVLC                         Equity: U.S. - Large Cap
# CVMC                           Equity: U.S. - Mid Cap
# CVIE    Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                         Equity: U.S. - Large Cap
# USCA                         Equity: U.S. Environment
#
#                               Issuer Expense Ratio       AUM
# Ticker
# SPY     State Street Global Advisors         0.09%  $374.42B
# IVV                        Blackrock         0.03%  $306.66B
# VOO                         Vanguard         0.03%  $287.12B
# VTI                         Vanguard         0.03%  $282.79B
# QQQ                          Invesco         0.20%  $172.68B
# ...                              ...           ...       ...
# CVLC                  Morgan Stanley         0.15%        --
# CVMC                  Morgan Stanley         0.15%        --
# CVIE                  Morgan Stanley         0.18%        --
# CDEI                  Morgan Stanley         0.14%        --
# USCA                             DWS         0.07%        --
#
# [3125 rows x 5 columns]

# %% [markdown]
# # União tabelas

# %%
base_dados_etfs = tabela_cadastro_etfs.join(tabela_rentabilidade_etfs, how = 'inner')
base_dados_etfs
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VOO                                  Vanguard S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
# USCA         Xtrackers MSCI USA Climate Action Equity ETF
#
#                                               Segment  \
# Ticker
# SPY                          Equity: U.S. - Large Cap
# IVV                          Equity: U.S. - Large Cap
# VOO                          Equity: U.S. - Large Cap
# VTI                       Equity: U.S. - Total Market
# QQQ                          Equity: U.S. - Large Cap
# ...                                               ...
# CVLC                         Equity: U.S. - Large Cap
# CVMC                           Equity: U.S. - Mid Cap
# CVIE    Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                         Equity: U.S. - Large Cap
# USCA                         Equity: U.S. Environment
#
#                               Issuer Expense Ratio       AUM   1 Year 3 Years  \
# Ticker
# SPY     State Street Global Advisors         0.09%  $374.42B   -9.01%  19.91%
# IVV                        Blackrock         0.03%  $306.66B   -9.02%  19.97%
# VOO                         Vanguard         0.03%  $287.12B   -9.02%  19.98%
# VTI                         Vanguard         0.03%  $282.79B  -10.30%  19.93%
# QQQ                          Invesco         0.20%  $172.68B  -12.94%  21.03%
# ...                              ...           ...       ...      ...     ...
# CVLC                  Morgan Stanley         0.15%        --       --      --
# CVMC                  Morgan Stanley         0.15%        --       --      --
# CVIE                  Morgan Stanley         0.18%        --       --      --
# CDEI                  Morgan Stanley         0.14%        --       --      --
# USCA                             DWS         0.07%        --       --      --
#
#        5 Years
# Ticker
# SPY     11.05%
# IVV     11.06%
# VOO     11.07%
# VTI     10.25%
# QQQ     15.65%
# ...        ...
# CVLC        --
# CVMC        --
# CVIE        --
# CDEI        --
# USCA        --
#
# [3125 rows x 8 columns]
